# %%
from PIL import Image
import numpy as np

img = Image.open("digit (3).png").convert("L").resize((28,28))
arr = np.array(img) / 255.0
arr = arr.reshape(1,28,28)

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import tensorflow as tf 
from tensorflow import keras
import seaborn as sns

# %%
(X_train,y_train), (X_test,y_test) = keras.datasets.mnist.load_data()

# %%
X_train = X_train/255
X_test = X_test/255

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(100,activation='sigmoid'),
    keras.layers.Dense(100,activation='sigmoid'),
    keras.layers.Dense(10,activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train,y_train,epochs=10)
# Out:
# C:\Users\shiva\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8779 - loss: 0.4629
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9469 - loss: 0.1780
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9625 - loss: 0.1257
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9715 - loss: 0.0950
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9779 - loss: 0.0739
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9823 - loss: 0.0586
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9856 - loss: 0.0472
# Epoch 8/10
# ...

# %%
y_pred = model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
plt.matshow(X_test[10])

# %%
np.argmax(y_pred[10])
# Out:
# 0

# %%
y_pred
# Out:
# array([[2.2371989e-07, 5.7933785e-06, 1.3034764e-05, ..., 9.9954706e-01,
#         1.5803566e-07, 3.9351340e-05],
#        [1.1350419e-07, 1.0087375e-04, 9.9985254e-01, ..., 7.1630495e-07,
#         4.8789066e-06, 1.1794624e-09],
#        [2.2370958e-08, 9.9973589e-01, 3.1282827e-05, ..., 1.9046603e-05,
#         1.7709650e-04, 8.9285504e-07],
#        ...,
#        [2.1736030e-08, 4.5025860e-08, 7.2217259e-09, ..., 2.6102123e-06,
#         4.3980904e-06, 3.7000445e-04],
#        [7.3373996e-09, 6.3436730e-08, 2.0130777e-09, ..., 2.5945599e-08,
#         1.9162532e-04, 2.7580332e-10],
#        [3.2617805e-07, 2.5480026e-07, 1.2054704e-07, ..., 2.7601175e-11,
#         9.2175405e-08, 2.5143372e-08]], dtype=float32)

# %%
array = [np.argmax(i) for i in y_pred]

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=array)
plt.figure(figsize=(16,8))
sns.heatmap(cm,annot=True,fmt='d')
plt.ylabel('True Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
array[10]
# Out:
# 0

# %%
y_pred1 = model.predict(arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
plt.matshow(arr[0])

# %%
array2 = [np.argmax(y_pred) for i in y_pred]

# %%
array2
# Out:
# [3]
